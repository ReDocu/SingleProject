# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

start_level = 0
end_level = 1

problem_dict = {}

columns = ['p_id','p_name','p_href','p_level','p_answer_people','try_count','category']

problem_df = pd.DataFrame(columns=columns)

for level in range(start_level,end_level + 1):
    
    url = 'https://solved.ac/problems/level/{}?page=1'.format(level)
    res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')
    
    maxpage = int(soup.select('div.css-18lc7iz > a')[-1].text.strip())
    
    for page in range(1, maxpage + 1):
        print(page)
        url = 'https://solved.ac/problems/level/{}?page={}'.format(level, page)

        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')

        path = 'tbody > tr'
        
        for item in soup.select(path):
            number = 0
            name = ''
            answer_people = 0
            try_count = 0.0
            href = ''
            # a 태그 찾기
            try:
                number = item.select('td')[0].select('a')[0].text
            except:
                print('0번 a태그가 존재하지 않습니다.')

            try:
                href = item.select('td')[0].select('a')[0]['href']
            except:
                print('하이퍼링크를 찾지 못했습니다.')    

            # a 태그 찾기
            try:
                name = item.select('td')[1].select('a')[0].text
            except:
                print('1번 a태그가 존재하지 않습니다.')

            try:
                answer_people = item.select('td')[2].select('div')[0].text
            except:
                print('2번 div 태그가 존재하지 않습니다.')

            try:
                try_count = item.select('td')[3].select('div')[0].text
            except:
                print('3번 div 태그가 존재하지 않습니다.')
                
                
            problem_df.loc[len(problem_df)] = [number,name,href,level,answer_people,try_count,np.NaN]

        
problem_df
# Out:
# 1
# 144
# 1
# 4
#      p_id     p_name                                 p_href  p_level  \
# 0    1223      마법의 돌   https://www.acmicpc.net/problem/1223        0
# 1    1237       정ㅋ벅ㅋ   https://www.acmicpc.net/problem/1237        0
# 2    1274       커피숍1   https://www.acmicpc.net/problem/1274        0
# 3    1299  전쟁 - 탈출편2   https://www.acmicpc.net/problem/1299        0
# 4    1317      그룹 단어   https://www.acmicpc.net/problem/1317        0
# ..    ...        ...                                    ...      ...
# 95  10171        고양이  https://www.acmicpc.net/problem/10171        1
# 96  10172          개  https://www.acmicpc.net/problem/10172        1
# 97  10189       Hook  https://www.acmicpc.net/problem/10189        1
# 98  10430        나머지  https://www.acmicpc.net/problem/10430        1
# 99  10699      오늘 날짜  https://www.acmicpc.net/problem/10699        1
#
#    p_answer_people try_count  category
# 0                2      8.00       NaN
# 1           19,905      3.17       NaN
# 2               31     11.61       NaN
# 3               10      7.70       NaN
# 4               14      6.71       NaN
# ..             ...       ...       ...
# 95         160,539      2.86       NaN
# 96         157,529      2.36       NaN
# 97           3,516      1.10       NaN
# 98         170,683      1.92       NaN
# 99          27,546      1.82       NaN
#
# [100 rows x 7 columns]

# %%
problem_df.to_csv('problem.csv')

# %%
problem_df[problem_df['p_level'] == 0]
# Out:
#     p_id       p_name                                p_href  p_level  \
# 0   1223        마법의 돌  https://www.acmicpc.net/problem/1223        0
# 1   1237         정ㅋ벅ㅋ  https://www.acmicpc.net/problem/1237        0
# 2   1274         커피숍1  https://www.acmicpc.net/problem/1274        0
# 3   1299    전쟁 - 탈출편2  https://www.acmicpc.net/problem/1299        0
# 48  1968          우체부  https://www.acmicpc.net/problem/1968        0
# 49  1973        버스 노선  https://www.acmicpc.net/problem/1973        0
#
#    p_answer_people try_count  category
# 0                2      8.00       NaN
# 1           19,905      3.17       NaN
# 2               31     11.61       NaN
# 3               10      7.70       NaN
# 4               14      6.71       NaN
# 5               65      4.45       NaN
# 6                3      2.00       NaN
# 7                4      2.00       NaN
# 8                3      6.33       NaN
# 9                4     21.25       NaN
# 10               8      2.50       NaN
# 11               5     18.60       NaN
# 12               7      6.29       NaN
# 13               2      4.00       NaN
# 14               2      1.50       NaN
# 15               4      5.75       NaN
# 16               4      3.25       NaN
# 17               7      1.14       NaN
# 18               6      2.00       NaN
# 19               2      3.00       NaN
# 20               5      2.60       NaN
# 21               2      3.50       NaN
# 22               4      3.75       NaN
# 23               6      2.83       NaN
# 24               3      3.67       NaN
# 25               5      3.20       NaN
# 26               4      4.00       NaN
# 27               2      9.00       NaN
# 28              10      2.60       NaN
# 29               3      1.00       NaN
# 30               3      5.33       NaN
# 31               5      1.20       NaN
# 32             131      3.32       NaN
# 33               2      6.00       NaN
# 34               6      3.83       NaN
# 35               5      8.40       NaN
# 36               8      2.75       NaN
# 37               3      5.67       NaN
# 38               3      2.00       NaN
# 39               3     14.67       NaN
# 40               5      1.20       NaN
# 41               5      1.40       NaN
# 42               2      2.00       NaN
# 43               2      3.00       NaN
# 44               3      2.00       NaN
# 45               2      2.00       NaN
# 46               3      1.67       NaN
# 47               2      6.50       NaN
# 48              10      2.50       NaN
# 49               2     14.00       NaN

# %%
    
    

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

path = 'tbody > tr'
#__next > div.css-1948bce > div:nth-child(4) > div.css-qijqp5 > table > tbody > tr:nth-child(1)
for item in soup.select(path):
    
    number = 0
    name = ''
    answer_people = 0
    try_count = 0.0
    href = 0
    # a 태그 찾기
    try:
        number = item.select('td')[0].select('a')[0].text
    except:
        print('0번 a태그가 존재하지 않습니다.')
        
    try:
        href = item.select('td')[0].select('a')[0]['href']
    except:
        print('하이퍼링크를 찾지 못했습니다.')    
    
    # a 태그 찾기
    try:
        name = item.select('td')[1].select('a')[0].text
    except:
        print('1번 a태그가 존재하지 않습니다.')
    
    try:
        answer_people = item.select('td')[2].select('div')[0].text
    except:
        print('2번 div 태그가 존재하지 않습니다.')
        
    try:
        try_count = item.select('td')[3].select('div')[0].text
    except:
        print('3번 div 태그가 존재하지 않습니다.')
    
  
    print(number, '/', name, '/', answer_people, '/', try_count, '/', href)    
    print()

# %%
import pandas as pd

columns = ['p_id','p_name','p_href','p_level','p_answer_people','try_count','category']

problem_df = pd.DataFrame(columns=columns)
problem_df

problem_df.loc[len(problem_df)] = [1,2,3,4,5,6,7]

# %%
problem_df.loc[len(problem_df)] = [1,2,3,4,5,6,7]

# %%
problem_df
# Out:
#    p_id  p_name  p_href  p_level  p_answer_people  try_count  category
# 0     1       2       3        4                5          6         7
# 1     1       2       3        4                5          6         7
