# %%
import tkinter

window=tkinter.Tk()
window.title("TEST")
window.geometry("640x480+100+100")
window.resizable(False, False)

listbox = tkinter.Listbox(window, selectmode='extended', height=0)
listbox.insert(0, "1번")
listbox.insert(1, "2번")
listbox.insert(2, "2번")
listbox.insert(3, "2번")
listbox.insert(4, "3번")
listbox.delete(1, 2)
listbox.pack()

window.mainloop()

# %%
import tkinter

window=tkinter.Tk()
window.title("TEST")
window.geometry("640x400+100+100")
window.resizable(False, False)

count=0

def countUP():
    global count
    count +=1
    label.config(text=str(count))

label = tkinter.Label(window, text="0")
label.pack()

button = tkinter.Button(window, overrelief="solid", width=15, command=countUP, repeatdelay=1000, repeatinterval=100)
button.pack()

window.mainloop()

# %%
import pandas as pd

import tkinter

window=tkinter.Tk()

window.title("TEST")
window.geometry("640x400+100+100")
window.resizable(False, False)

def countUP():
    global count
    count +=1
    label.config(text=str(count))

df = pd.read_csv(r'Video_Games_Sales_as_at_22_Dec_2016.csv')

listbox = tkinter.Listbox(window, selectmode='extended', height=0)

listbox.insert()


listbox.insert(0, "1번")

listbox.delete(1, 2)
listbox.pack()

label = tkinter.Label(window, text="0")
label.pack()

button = tkinter.Button(window, overrelief="solid", width=15, command=countUP, repeatdelay=1000, repeatinterval=100)
button.pack()


window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 20
#      16 df = pd.read_csv(r'Video_Games_Sales_as_at_22_Dec_2016.csv')
#      18 listbox = tkinter.Listbox(window, selectmode='extended', height=0)
# ---> 20 listbox.insert()
#      23 listbox.insert(0, "1번")
#      25 listbox.delete(1, 2)
#
# TypeError: Listbox.insert() missing 1 required positional argument: 'index'

# %%
import tkinter
import tkinter.ttk

window=tkinter.Tk()
window.title("YUN DAE HEE")
window.geometry("640x400+100+100")
window.resizable(False, False)

def cc(self):
    treeview.tag_configure("tag2", background="red")

treeview=tkinter.ttk.Treeview(window, columns=["one", "two"], displaycolumns=["two", "one"])
treeview.pack()

treeview.column("#0", width=70)
treeview.heading("#0", text="num")

treeview.column("one", width=100, anchor="center")
treeview.heading("one", text="문자", anchor="e")

treeview.column("#2", width=100, anchor="w")
treeview.heading("two", text="ASCII", anchor="center")

treelist=[("A", 65), ("B", 66), ("C", 67), ("D", 68), ("E", 69)]

for i in range(len(treelist)):
    
    treeview.insert('', 'end', text=i, values=treelist[i], iid=str(i)+"번")

top=treeview.insert('', 'end', text=str(len(treelist)), iid="5번", tags="tag1")
top_mid1=treeview.insert(top, 'end', text="5-2", values=["SOH", 1], iid="5번-1")
top_mid2=treeview.insert(top, 0, text="5-1", values=["NUL", 0], iid="5번-0", tags="tag2")
top_mid3=treeview.insert(top, 'end', text="5-3", values=["STX", 2], iid="5번-2", tags="tag2")

treeview.tag_bind("tag1", sequence="<<TreeviewSelect>>", callback=cc)

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[78], line 6
#       4 window=tkinter.Tk()
#       5 window.title("YUN DAE HEE")
# ----> 6 window.geometry("TEST")
#       7 window.resizable(False, False)
#       9 def cc(self):
#
# File c:\Users\GJ\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:2114, in Wm.wm_geometry(self, newGeometry)
#    2111 def wm_geometry(self, newGeometry=None):
#    2112     """Set geometry to NEWGEOMETRY of the form =widthxheight+x+y. Return
#    2113     current value if None is given."""
# -> 2114     return self.tk.call('wm', 'geometry', self._w, newGeometry)
#
# TclError: bad geometry specifier "TEST"

# %%
import tkinter

window.title("TEST")
window.geometry("640x400+100+100")
window.resizable(False, False)

import pandas as pd

df = pd.read_csv(r'Video_Games_Sales_as_at_22_Dec_2016.csv')
df.head()
list(df.columns)


treeview.column("#0", width=70)
treeview.heading("#0", text="num")

treeview.column("one", width=100, anchor="center")
treeview.heading("one", text="문자", anchor="e")

treeview.column("#2", width=100, anchor="w")
treeview.heading("two", text="ASCII", anchor="center")

# %%
import pandas as pd
df = pd.read_csv(r'Video_Games_Sales_as_at_22_Dec_2016.csv')
#df_dict = df.loc[:].to_dict()
#for item in df.loc[0:df.size]:
#    print(item)

# %%
import pandas as pd
import tkinter
from tkinter import ttk

window=tkinter.Tk()
window.title("TEST")
window.geometry("640x400+100+100")
window.resizable(False, False)

df = pd.read_csv(r'Video_Games_Sales_as_at_22_Dec_2016.csv')

#df_dict = df.loc[:].to_dict()
#for key, value in df_dict.items():
#    print(key,value)
#for value in 

treeview=tkinter.ttk.Treeview(window, columns=list(df.columns), displaycolumns=list(df.columns))
treeview.pack()

for item in list(df.columns):
    treeview.column(item, width=len((item) * 10), anchor="center")
    treeview.heading(item, text=item, anchor="center")

treelist = []
for i in range(len(df)):
    treelist.append(df.loc[i].to_list())

for i in range(len(treelist)):
    treeview.insert('', 'end', text=i, values=treelist[i], iid=str(i)+"번")


# add a scrollbar
scrollbar = ttk.Scrollbar(window, orient=tkinter.VERTICAL, command=treeview.yview)
window.configure(yscroll=scrollbar.set)
scrollbar.grid(row=0, column=1, sticky='ns')

#button = tkinter.Button(window, overrelief="solid", width=15, command=countUP, repeatdelay=1000, repeatinterval=100)
#button.pack()


window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[72], line 34
#      32 # add a scrollbar
#      33 scrollbar = ttk.Scrollbar(window, orient=tkinter.VERTICAL, command=treeview.yview)
# ---> 34 window.configure(yscroll=scrollbar.set)
#      35 scrollbar.grid(row=0, column=1, sticky='ns')
#      37 #button = tkinter.Button(window, overrelief="solid", width=15, command=countUP, repeatdelay=1000, repeatinterval=100)
#      38 #button.pack()
#
# File c:\Users\GJ\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:1716, in Misc.configure(self, cnf, **kw)
#    1709 def configure(self, cnf=None, **kw):
#    1710     """Configure resources of a widget.
#    1711
#    1712     The values for resources are specified as keyword
#    1713     arguments. To get an overview about
#    1714     the allowed keyword arguments call the method keys.
#    1715     """
# -> 1716     return self._configure('configure', cnf, kw)
#
# File c:\Users\GJ\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:1706, in Misc._configure(self, cmd, cnf, kw)
#    1704 if isinstance(cnf, str):
#    1705     return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# -> 1706 self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
#
# TclError: unknown option "-yscroll"

# %%
import tkinter
import tkinter.ttk

window=tkinter.Tk()
window.title("TEST")
window.geometry("640x400+100+100")
window.resizable(False, False)

def cc(self):
    treeview.tag_configure("tag2", background="red")

treeview=tkinter.ttk.Treeview(window, columns=["one", "two"], displaycolumns=["two", "one"])
treeview.pack()

treeview.column("#0", width=70)
treeview.heading("#0", text="num")

treeview.column("one", width=100, anchor="center")
treeview.heading("one", text="문자", anchor="e")

treeview.column("#2", width=100, anchor="w")
treeview.heading("two", text="ASCII", anchor="center")

treelist=[("A", 65), ("B", 66), ("C", 67), ("D", 68), ("E", 69)]

for i in range(len(treelist)):
    
    treeview.insert('', 'end', text=i, values=treelist[i], iid=str(i)+"번")

top=treeview.insert('', 'end', text=str(len(treelist)), iid="5번", tags="tag1")
top_mid1=treeview.insert(top, 'end', text="5-2", values=["SOH", 1], iid="5번-1")
top_mid2=treeview.insert(top, 0, text="5-1", values=["NUL", 0], iid="5번-0", tags="tag2")
top_mid3=treeview.insert(top, 'end', text="5-3", values=["STX", 2], iid="5번-2", tags="tag2")

treeview.tag_bind("tag1", sequence="<<TreeviewSelect>>", callback=cc)

window.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
from tkinter.messagebox import showinfo

root = tk.Tk()
root.title('Treeview demo')
root.geometry('620x200')

# define columns
columns = ('first_name', 'last_name', 'email')

tree = ttk.Treeview(root, columns=columns, show='headings')

# define headings
tree.heading('first_name', text='First Name')
tree.heading('last_name', text='Last Name')
tree.heading('email', text='Email')

# generate sample data
contacts = []
for n in range(1, 100):
    contacts.append((f'first {n}', f'last {n}', f'email{n}@example.com'))

# add data to the treeview
for contact in contacts:
    tree.insert('', tk.END, values=contact)


def item_selected(event):
    for selected_item in tree.selection():
        item = tree.item(selected_item)
        record = item['values']
        # show a message
        showinfo(title='Information', message=','.join(record))


tree.bind('<<TreeviewSelect>>', item_selected)

tree.grid(row=0, column=0, sticky='nsew')

# add a scrollbar
scrollbar = ttk.Scrollbar(root, orient=tk.VERTICAL, command=tree.yview)
tree.configure(yscroll=scrollbar.set)
scrollbar.grid(row=0, column=1, sticky='ns')

# run the app
root.mainloop()

# %%
from tkinter import ttk
import tkinter as tk

window = tk.Tk()
window.title('TEST')
window.geometry("640x400+100+100")
window.resizable(False, False)

treeview = tkinter.ttk.Treeview(window, columns=['one','two'], displaycolumns=['one','two'])
treeview.pack()



window.mainloop()
